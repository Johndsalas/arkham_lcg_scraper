# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_player_cards.csv')
len(df)
# Out:
# 1116

# %%
gator = df[df.type == 'investigator']

# %%
gator
# Out:
#      faction          type cost             traits  \
# 0   survivor  investigator   --            drifter
# 1      rogue  investigator   --           criminal
# 2     mystic  investigator   --           sorcerer
# 3     mystic  investigator   --           sorcerer
# 4      rogue  investigator   --  drifter socialite
# ..       ...           ...  ...                ...
# 56  survivor  investigator   --             warden
# 57  guardian  investigator   --            drifter
# 58     rogue  investigator   --           criminal
# 59  guardian  investigator   --    believer hunter
# 60  guardian  investigator   --    believer hunter
#
#                                               ability icons willpower  \
# 0   begin game duke play fastaction discard card h...    --         4
# 1   fastaction turn spend resource may take additi...    --         2
# 2   reaction horror placed agnes baker deal damage...    --         5
# ...

# %%
df.columns
# Out:
# Index(['title', 'faction', 'type', 'cost', 'traits', 'ability', 'icons',
#        'willpower', 'intellect', 'combat', 'agility', 'health', 'sanity', 'xp',
#        'artist', 'expansion', 'flavor', 'deck_building', 'story', 'url'],
#       dtype='object')
